# %% [markdown]
# ## Población por comunas

# %% [markdown]
# Con el objetivo de llevar a cabo un análisis efectivo de los KPIs, se recopiló información sobre la población de las comunas a lo largo de los años.

# %%
import pandas as pd
import calendar
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bda60b61-bb14-4cf1-aa23-c6f9782ba71d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bda60b61-bb14-4cf1-aa23-c6f9782ba71d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Visualizacion de datos

# %%
df_poblacion = pd.read_excel('EXCEL CON DATOS POBLACIONALES.xls')

# %% [markdown]
# ## Visualizacion de datos

# %%
df_poblacion
# Out:
#    Proyecciones de población por comuna y sexo. Ciudad de Buenos Aires. Años 2010/2025  \
# 0                                         Ambos sexos
# 1                                              Comuna
# 2                                               Total
# 3                                                   1
# 4                                                   2
# 5                                                   3
# 6                                                   4
# 7                                                   5
# 8                                                   6
# 9                                                   7
# 10                                                  8
# 11                                                  9
# 12                                                 10
# 13                                                 11
# 14                                                 12
# 15                                                 13
# ...

# %% [markdown]
# Son tres tablas unidas así que se procede a dividirlas

# %%
df_poblacion_ambos = df_poblacion.iloc[0:16, :13]
df_poblacion_masculino = df_poblacion.iloc[20:35, :13]
df_poblacion_femenino = df_poblacion.iloc[40:55, :13]

# %%
df_poblacion_ambos
# Out:
#    Proyecciones de población por comuna y sexo. Ciudad de Buenos Aires. Años 2010/2025  \
# 0                                         Ambos sexos
# 1                                              Comuna
# 2                                               Total
# 3                                                   1
# 4                                                   2
# 5                                                   3
# 6                                                   4
# 7                                                   5
# 8                                                   6
# 9                                                   7
# 10                                                  8
# 11                                                  9
# 12                                                 10
# 13                                                 11
# 14                                                 12
# 15                                                 13
#
# ...

# %%
df_poblacion_masculino
# Out:
#    Proyecciones de población por comuna y sexo. Ciudad de Buenos Aires. Años 2010/2025  \
# 20                                             Comuna
# 21                                              Total
# 22                                                  1
# 23                                                  2
# 24                                                  3
# 25                                                  4
# 26                                                  5
# 27                                                  6
# 28                                                  7
# 29                                                  8
# 30                                                  9
# 31                                                 10
# 32                                                 11
# 33                                                 12
# 34                                                 13
#
# ...

# %%
df_poblacion_femenino
# Out:
#    Proyecciones de población por comuna y sexo. Ciudad de Buenos Aires. Años 2010/2025  \
# 40                                             Comuna
# 41                                              Total
# 42                                                  1
# 43                                                  2
# 44                                                  3
# 45                                                  4
# 46                                                  5
# 47                                                  6
# 48                                                  7
# 49                                                  8
# 50                                                  9
# 51                                                 10
# 52                                                 11
# 53                                                 12
# 54                                                 13
#
# ...

# %% [markdown]
# ## Se cargan los nuevos dataframes

# %%
from google.colab import files

df_poblacion_ambos.to_csv("df_poblacion_ambos.csv", index=False)
df_poblacion_masculino.to_csv("df_poblacion_masculino.csv", index=False)
df_poblacion_femenino.to_csv("df_poblacion_femenino.csv", index=False)


files.download('df_poblacion_ambos.csv')

files.download('df_poblacion_masculino.csv')

files.download('df_poblacion_femenino.csv')
